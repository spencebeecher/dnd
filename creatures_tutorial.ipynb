# %%
from creatures import get_creatures_df

# %%
creatures = get_creatures_df()
creatures.head()
# Out:
#                     name source  page    size       type alignment  \
# 0             Fume Drake   DoSI  41.0     [S]  elemental       [N]
# 1        Kobold Tinkerer   DoSI  43.0     [S]   humanoid       [A]
# 2  Spore Servant Octopus   DoSI  46.0     [L]      plant       [U]
# 3             Athar Null    MPP  53.0  [S, M]   humanoid       [A]
# 4       Aurumach Rilmani    MPP  43.0     [L]  celestial       [N]
#
#   alignmentPrefix                                                 ac  \
# 0      typically                                                [12]
# 1             NaN                                               [12]
# 2             NaN                                               [11]
# 3             NaN  [{'ac': 14, 'from': ['{@item leather armor|PHB...
# 4      typically             [{'ac': 18, 'from': ['natural armor']}]
#
#    hp_average   hp_formula  ...  conditionImmune_incapacitated  basicRules  \
# ...
